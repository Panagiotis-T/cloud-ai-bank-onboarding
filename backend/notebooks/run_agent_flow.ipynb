# %%
import sys
sys.path.insert(0, 'src/')

from app.agent import chat
chat()

# %%
# What documents do I need for if I am from Sweden?
# Which branch is responsible for customers in Copenhagen with postal code 1300?
